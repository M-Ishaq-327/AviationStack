# %%
import requests

API_KEY = "8f0183565ea17e53cd2856c1e9957c66"

url = "http://api.aviationstack.com/v1/flights"
params = {
    "access_key": API_KEY,
    "airline_iata": "PK",
    "limit": 50
}

response = requests.get(url, params=params)
data = response.json()

print(data)
# Out:
# {'pagination': {'limit': 50, 'offset': 0, 'count': 50, 'total': 370}, 'data': [{'flight_date': '2026-04-16', 'flight_status': 'scheduled', 'departure': {'airport': 'Geneve-cointrin', 'timezone': 'Europe/Zurich', 'iata': 'GVA', 'icao': 'LSGG', 'terminal': '1', 'gate': None, 'delay': None, 'scheduled': '2026-04-16T14:40:00+00:00', 'estimated': '2026-04-16T14:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Istanbul Airport', 'timezone': 'Europe/Istanbul', 'iata': 'IST', 'icao': 'LTFM', 'terminal': None, 'gate': None, 'baggage': None, 'scheduled': '2026-04-16T18:55:00+00:00', 'delay': 10, 'estimated': None, 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Pakistan International Airlines', 'iata': 'PK', 'icao': 'PIA'}, 'flight': {'number': '5922', 'iata': 'PK5922', 'icao': 'PIA5922', 'codeshared': {'airline_name': 'turkish airlines', 'airline_iata': 'tk', 'airline_icao': 'thy', 'flight_number': '
# ...

# %%
import json

# 🔹 Save raw JSON (exact API response)
with open("flights_raw.json", "w") as file:
    json.dump(data, file, indent=4)

print("✅ Raw JSON saved!")
